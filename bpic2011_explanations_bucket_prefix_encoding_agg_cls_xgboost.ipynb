# %% [markdown]
# # BPIC 2011
# #### Bucket - Prefix length
# ####  Encoding - Aggregation
# ####  Classifier - XGBoost

# %%
import EncoderFactory
from DatasetManager import DatasetManager
import BucketFactory

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import lime
import lime.lime_tabular
from lime import submodular_pick;
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Utility function to generate feature importance of XGBoost

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def imp_df(column_names, importances):
        df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
        return df

# plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title, num_feat):
        imp_df.columns = ['feature', 'feature_importance']
        b= sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df.head(num_feat), orient = 'h', palette="Blues_r") 
        b.set_title(title, fontsize = 14) 
    
        for item in b.get_yticklabels():
            item.set_fontsize(13)

# %%
def generate_global_explanations(train_X,train_Y, cls, feature_combiner):
    
    print("The number of testing instances is ",len(train_Y))
    print("The total number of columns is",train_X.shape[1]);
    print("The total accuracy is ",cls.score(train_X,train_Y));
       
    sns.set(style="darkgrid")
    sns.set(rc={'figure.figsize':(10,10), "font.size":18,"axes.titlesize":18,"axes.labelsize":18})
    sns.set
    feat_names = feature_combiner.get_feature_names()
    base_imp = imp_df(feat_names, cls.feature_importances_)
    base_imp.head(15)
    #var_imp_plot(base_imp, 'Feature importance using Random forest', 15)
    return base_imp

# %% [markdown]
# ### Generate Local Explanations using LIME

# %%
from lime import submodular_pick
def generate_local_explanations(explainer,test_xi, cls,test_y, submod=False, test_all_data=None):
    
    print("Actual value ", test_y)
    num_features=6;# maximum is 6 ,if it is larger than 6, the features displayed are different.
    exp = explainer.explain_instance(test_xi, 
                                 cls.predict_proba, num_features=num_features, labels=[0,1])
    
    #exp.show_in_notebook(show_table=True, show_all=False);
    probability_result=cls.predict_proba([test_xi])[0];
    print(probability_result);
    print ('Explanation for class %s' % class_names[1])
    print ('\n'.join(map(str, exp.as_list(label=1))))
    return exp
    #%matplotlib inline
    #fig = exp.as_pyplot_figure()
        
    if submod==True:
        sp_obj=submodular_pick.SubmodularPick(explainer, test_all_data, cls.predict_proba, 
                                      sample_size=20, num_features=num_features,num_exps_desired=4)
        [exp.as_pyplot_figure(label=exp.available_labels()[0]) for exp in sp_obj.sp_explanations];

# %% [markdown]
# ### Benchmark code
# 1. Contain additional updates to include generation of importances
# 2. Stores classification for prefix lengths of 5,10, 15, 20 and 25

# %%
dataset_ref = "bpic2011"
params_dir = "params"
results_dir = "results"
bucket_method = "prefix"
cls_encoding = "agg"
cls_method = "xgboost"
gap = 1
n_iter = 1

if bucket_method == "state":
    bucket_encoding = "last"
else:
    bucket_encoding = "agg"

method_name = "%s_%s"%(bucket_method, cls_encoding)

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2011": ["bpic2011_f%s"%formula for formula in range(4,5)],
    "bpic2012" : ["bpic2012_accepted"]
    #"insurance": ["insurance_activity", "insurance_followup"],
    #"sepsis_cases": ["sepsis_cases_1", "sepsis_cases_2", "sepsis_cases_4"]
}

encoding_dict = {
    "laststate": ["static", "last"],
    "agg": ["static", "agg"],
    "index": ["static", "index"],
    "combined": ["static", "last", "agg"]
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]
methods = encoding_dict[cls_encoding]
    
train_ratio = 0.8
random_state = 22

# create results directory
if not os.path.exists(os.path.join(params_dir)):
    os.makedirs(os.path.join(params_dir))
    
print(datasets)
# Out:
# ['bpic2011_f4']

# %%
for dataset_name in datasets:
    
    # load optimal params
    optimal_params_filename = os.path.join(params_dir, "optimal_params_%s_%s_%s.pickle" % (cls_method, dataset_name, method_name))
    print(optimal_params_filename)
    if not os.path.isfile(optimal_params_filename) or os.path.getsize(optimal_params_filename) <= 0:
        continue
        
    with open(optimal_params_filename, "rb") as fin:
        args = pickle.load(fin)
        
    print(args)
    bucket_list=[5,10,15,20,25] #:)
    # read the data
    dataset_manager = DatasetManager(dataset_name)
    data = dataset_manager.read_dataset()
    cls_encoder_args = {'case_id_col': dataset_manager.case_id_col, 
                        'static_cat_cols': dataset_manager.static_cat_cols,
                        'static_num_cols': dataset_manager.static_num_cols, 
                        'dynamic_cat_cols': dataset_manager.dynamic_cat_cols,
                        'dynamic_num_cols': dataset_manager.dynamic_num_cols, 
                        'fillna': True}

    # determine min and max (truncated) prefix lengths
    min_prefix_length = 1
    if "traffic_fines" in dataset_name:
        max_prefix_length = 10
    elif "bpic2017" in dataset_name:
        max_prefix_length = min(20, dataset_manager.get_pos_case_length_quantile(data, 0.90))
    else:
        max_prefix_length = min(40, dataset_manager.get_pos_case_length_quantile(data, 0.90))

    # split into training and test
    train, test = dataset_manager.split_data_strict(data, train_ratio, split="temporal")
    
    if gap > 1:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s_gap%s.csv" % (cls_method, dataset_name, method_name, gap))
    else:
        outfile = os.path.join(results_dir, "performance_results_%s_%s_%s.csv" % (cls_method, dataset_name, method_name))
        
    start_test_prefix_generation = time.time()
    dt_test_prefixes = dataset_manager.generate_prefix_data(test, min_prefix_length, max_prefix_length)
    test_prefix_generation_time = time.time() - start_test_prefix_generation
            
    offline_total_times = []
    online_event_times = []
    train_prefix_generation_times = []
    explained=False
    impotance=None
    exp_ddict=dict()
    exp_rdict=dict()
    model_dict=dict()
    importance_dict=dict()
    for ii in range(n_iter):
        # create prefix logs
        start_train_prefix_generation = time.time()
        dt_train_prefixes = dataset_manager.generate_prefix_data(train, min_prefix_length, max_prefix_length, gap)
        train_prefix_generation_time = time.time() - start_train_prefix_generation
        train_prefix_generation_times.append(train_prefix_generation_time)
            
        # Bucketing prefixes based on control flow
        bucketer_args = {'encoding_method':bucket_encoding, 
                         'case_id_col':dataset_manager.case_id_col, 
                         'cat_cols':[dataset_manager.activity_col], 
                         'num_cols':[], 
                         'random_state':random_state}
        if bucket_method == "cluster":
            bucketer_args["n_clusters"] = int(args["n_clusters"])
        bucketer = BucketFactory.get_bucketer(bucket_method, **bucketer_args)

        start_offline_time_bucket = time.time()
        bucket_assignments_train = bucketer.fit_predict(dt_train_prefixes)
        offline_time_bucket = time.time() - start_offline_time_bucket

        bucket_assignments_test = bucketer.predict(dt_test_prefixes)

        preds_all = []
        test_y_all = []
        nr_events_all = []
        offline_time_fit = 0
        current_online_event_times = []
        
        for bucket in set(bucket_assignments_test):
            print("Bucket" , bucket )
            #args has only one value - some error and so just using it
            #if bucket_method == "prefix":
            #    current_args = args[bucket]
            #else:
            current_args = args
            relevant_train_cases_bucket = dataset_manager.get_indexes(dt_train_prefixes)[bucket_assignments_train == bucket]
            relevant_test_cases_bucket = dataset_manager.get_indexes(dt_test_prefixes)[bucket_assignments_test == bucket]
            dt_test_bucket = dataset_manager.get_relevant_data_by_indexes(dt_test_prefixes, relevant_test_cases_bucket)
            
            nr_events_all.extend(list(dataset_manager.get_prefix_lengths(dt_test_bucket)))
            print('number events', len(nr_events_all))
            
            if len(relevant_train_cases_bucket) == 0:
                preds = [dataset_manager.get_class_ratio(train)] * len(relevant_test_cases_bucket)
                current_online_event_times.extend([0] * len(preds))
            else:
                dt_train_bucket = dataset_manager.get_relevant_data_by_indexes(dt_train_prefixes, relevant_train_cases_bucket) # one row per event
                train_y = dataset_manager.get_label_numeric(dt_train_bucket)

                if len(set(train_y)) < 2:
                    preds = [train_y[0]] * len(relevant_test_cases_bucket)
                    current_online_event_times.extend([0] * len(preds))
                    test_y_all.extend(dataset_manager.get_label_numeric(dt_test_bucket))
                else:
                    start_offline_time_fit = time.time()
                    feature_combiner = FeatureUnion([(method, EncoderFactory.get_encoder(method, **cls_encoder_args)) for method in methods])

                    if cls_method == "rf":
                        cls = RandomForestClassifier(n_estimators=500,
                                                     max_features=current_args['max_features'],
                                                     random_state=random_state)

                    elif cls_method == "xgboost":
                        cls = xgb.XGBClassifier(objective='binary:logistic',
                                                n_estimators=500,
                                                learning_rate= current_args['learning_rate'],
                                                subsample=current_args['subsample'],
                                                max_depth=int(current_args['max_depth']),
                                                colsample_bytree=current_args['colsample_bytree'],
                                                min_child_weight=int(current_args['min_child_weight']),
                                                seed=random_state)

                    elif cls_method == "logit":
                        cls = LogisticRegression(C=2**current_args['C'],
                                                 random_state=random_state)

                    elif cls_method == "svm":
                        cls = SVC(C=2**current_args['C'],
                                  gamma=2**current_args['gamma'],
                                  random_state=random_state)

                    if cls_method == "svm" or cls_method == "logit":
                        pipeline = Pipeline([('encoder', feature_combiner), ('scaler', StandardScaler()), ('cls', cls)])
                    else:
                        pipeline = Pipeline([('encoder', feature_combiner), ('cls', cls)])

                    pipeline.fit(dt_train_bucket, train_y)
                    #get the explainations for the model now
        
                    print("Training model iteration ", ii )
                    
                    #get the training data as a matrix
                    trainingdata=feature_combiner.fit_transform(dt_train_bucket);
                    if bucket in bucket_list:
                        importance = generate_global_explanations(trainingdata,train_y, cls, feature_combiner)
                        #create an explainer now that can be passed later
                        class_names=['regular','deviant']# regular is 0, deviant is 1, 0 is left, 1 is right
                        explainer = lime.lime_tabular.LimeTabularExplainer(trainingdata,
                                                    feature_names = feature_combiner.get_feature_names(),
                                                   class_names=class_names, discretize_continuous=True)
                        importance_dict[bucket]=importance
                        #exp_dict[bucket]=explainer
                        model_dict[bucket]=cls
                    
                    
                    offline_time_fit += time.time() - start_offline_time_fit

                    # predict separately for each prefix case
                    preds = []
                    
                    test_all_grouped = dt_test_bucket.groupby(dataset_manager.case_id_col)
                    print(dt_test_bucket.shape)
                    count_d=0
                    count_r=0
                    for _, group in test_all_grouped:
                        
                        test_y_group = dataset_manager.get_label_numeric(group)
                        test_y_all.extend(test_y_group)
                            
                        start = time.time()
                        _ = bucketer.predict(group)
                        
                        if cls_method == "svm":
                            pred = pipeline.decision_function(group)
                        else:
                            preds_pos_label_idx = np.where(cls.classes_ == 1)[0][0]
                            pred = pipeline.predict_proba(group)[:,preds_pos_label_idx]
                            #print(test_y_group)
                            if bucket in bucket_list and (count_d<3 or count_r<3):
                                test_x_group= feature_combiner.fit_transform(group)
                                print(test_x_group.shape,test_y_group[0], _)
                                test_x=np.transpose(test_x_group[0])
                                print('Generating local Explanations for', dataset_manager.get_case_ids(group))
                                exp=generate_local_explanations(explainer, test_x, cls, test_y_group )
                                if(test_y_group[0]==1):
                                    count_d=count_d+1
                                    exp_ddict[bucket+count_d]=exp
                                else:
                                    count_r=count_r+1
                                    exp_rdict[bucket+count_r]=exp
                                
                        pipeline_pred_time = time.time() - start
                        current_online_event_times.append(pipeline_pred_time / len(group))
                        preds.extend(pred)
                        

            preds_all.extend(preds)

      
   
        dt_results = pd.DataFrame({"actual": test_y_all, "predicted": preds_all, "nr_events": nr_events_all})
        for nr_events, group in dt_results.groupby("nr_events"):
            if len(set(group.actual)) < 2:
                print(dataset_name, method_name, cls_method, nr_events, "auc", np.nan)
            else:
                #if nr_events in [5, 10, 25] and explained=False:
                #    generate_local_explanations(explainer,group[j],cls )
                #    explained=True
                print(dataset_name, method_name, cls_method, nr_events, "auc", roc_auc_score(group.actual, group.predicted))
        print(dataset_name, method_name, cls_method, -1, -1, "auc", roc_auc_score(dt_results.actual, dt_results.predicted))
# Out:
# params\optimal_params_xgboost_bpic2011_f4_prefix_agg.pickle
# {'colsample_bytree': 0.7459515180000027, 'learning_rate': 0.6373187476692391, 'max_depth': 20, 'min_child_weight': 3, 'subsample': 0.8208008973160263}
# prefix
# Bucket 1
# number events 228
# Training model iteration  0
# (228, 26)
# Bucket 2
# number events 455
# Training model iteration  0
# (454, 26)
# Bucket 3
# number events 673
# Training model iteration  0
# (654, 26)
# Bucket 4
# number events 886
# Training model iteration  0
# (852, 26)
# Bucket 5
# number events 1093
# Training model iteration  0
# The number of testing instances is  722
# The total number of columns is 963
# The total accuracy is  1.0
# (1035, 26)
# (1, 963) 1 [5]
# Generating local Explanations for 0    1001_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.00274438 0.9972556 ]
# Explanation for class deviant
# ('static__Treatment code_TC803 > 0.00', 0.4598705078795807)
# ('static__Treatment code_TC603 <= 0.00', -0.19557258551587742)
# ('static__Treatment code_TC101 <= 0.00', 0.13789913129608264)
# ('agg__Producer code_LVPT <= 0.00', -0.12126809691781326)
# ('agg__mean_weekday <= 1.00', 0.07207835709531644)
# ('agg__sum_weekday <= 5.00', -0.07019363993790882)
# (1, 963) 1 [5]
# Generating local Explanations for 0    1002_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.31719744 0.68280256]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.45224517700578176)
# ('static__Treatment code_TC813 <= 0.00', -0.20347811906405952)
# ('static__Treatment code_TC603 <= 0.00', -0.1760928459583902)
# ('static__Treatment code_TC101 <= 0.00', 0.12822538156469238)
# ('agg__Producer code_LVPT > 0.00', 0.11568458236494912)
# ('2.00 < agg__max_weekday <= 6.00', -0.05937716861942604)
# (1, 963) 1 [5]
# Generating local Explanations for 0    1003_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.998686   0.00131401]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.46421209796077373)
# ('static__Treatment code_TC603 <= 0.00', -0.22906929723751288)
# ('static__Treatment code_TC813 <= 0.00', -0.19283468106575424)
# ('static__Treatment code_TC101 <= 0.00', 0.13363088795521516)
# ('agg__Producer code_LVPT <= 0.00', -0.12812612319758565)
# ('agg__Section_Section 2 > 3.00', 0.08047295377574021)
# (1, 963) 0 [5]
# Generating local Explanations for 0    1004_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.12265593 0.8773441 ]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.46581361097698737)
# ('static__Treatment code_TC603 <= 0.00', -0.18320053642794215)
# ('static__Treatment code_TC813 <= 0.00', -0.1590096669701751)
# ('agg__Producer code_LVPT > 0.00', 0.128369159940889)
# ('static__Treatment code_TC101 <= 0.00', 0.12583318947983918)
# ('static__Age > 70.00', 0.0565225567226087)
# (1, 963) 0 [5]
# Generating local Explanations for 0    1005_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.41797537 0.58202463]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4607947119822504)
# ('static__Treatment code_TC603 <= 0.00', -0.20792732678357131)
# ('static__Treatment code_TC813 <= 0.00', -0.19218819261943493)
# ('static__Treatment code_TC101 <= 0.00', 0.13854307584611064)
# ('agg__Producer code_LVPT <= 0.00', -0.11858576312516997)
# ('2.00 < agg__max_weekday <= 6.00', -0.06842994886009608)
# (1, 963) 1 [5]
# Generating local Explanations for 0    1006_5
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9978095  0.00219046]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.49065083527179476)
# ('static__Treatment code_TC603 <= 0.00', -0.21614099757145983)
# ('static__Treatment code_TC813 <= 0.00', -0.1812840270139587)
# ('static__Treatment code_TC101 <= 0.00', 0.13212345252710855)
# ('agg__Producer code_LVPT <= 0.00', -0.10339626447854279)
# ('agg__max_weekday <= 1.00', 0.06726975967800664)
# (1, 963) 0 [5]
# Generating local Explanations for 0    1007_5
# Name: Case ID, dtype: object
# Actual value  [0]
# [9.999195e-01 8.052351e-05]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4731815612211719)
# ('static__Treatment code_TC603 <= 0.00', -0.1947415802340225)
# ('static__Treatment code_TC813 <= 0.00', -0.17563987973538486)
# ('0.00 < static__Treatment code_TC101 <= 1.00', -0.13874809524038142)
# ('agg__Producer code_LVPT <= 0.00', -0.0985594321687964)
# ('356.00 < agg__min_open_cases <= 503.75', 0.06402076185715232)
# Bucket 6
# number events 1293
# Training model iteration  0
# (1200, 26)
# Bucket 7
# number events 1493
# Training model iteration  0
# (1400, 26)
# Bucket 8
# number events 1691
# Training model iteration  0
# (1584, 26)
# Bucket 9
# number events 1889
# Training model iteration  0
# (1782, 26)
# Bucket 10
# number events 2087
# Training model iteration  0
# The number of testing instances is  584
# The total number of columns is 965
# The total accuracy is  1.0
# (1980, 26)
# (1, 965) 1 [10]
# Generating local Explanations for 0    1001_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.001791 0.998209]
# Explanation for class deviant
# ('static__Treatment code_TC803 > 0.00', 0.5575802449265239)
# ('agg__mean_event_nr > 15.93', 0.12828760590176658)
# ('agg__group_General Lab Clinical Chemistry > 9.00', -0.11856811838987338)
# ('static__Treatment code_TC101 <= 0.00', 0.10982979213607368)
# ('agg__std_event_nr > 6.83', 0.10458689358689688)
# ('static__Diagnosis code_M16 <= 0.00', 0.09621675868412707)
# (1, 965) 1 [10]
# Generating local Explanations for 0    1002_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.95393646 0.04606352]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.5267737887881436)
# ('static__Treatment code_TC603 <= 0.00', -0.17622658291735863)
# ('agg__std_event_nr > 6.83', 0.13051015292589396)
# ('static__Diagnosis code_M16 <= 0.00', 0.10175850081055786)
# ('static__Treatment code_TC101 <= 0.00', 0.10009105189865351)
# ('6.30 < agg__mean_event_nr <= 13.80', -0.09877549073033086)
# (1, 965) 1 [10]
# Generating local Explanations for 0    1003_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [9.9914569e-01 8.5428695e-04]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.5467694552115969)
# ('agg__std_event_nr > 6.83', 0.11680441903246996)
# ('static__Treatment code_TC101 <= 0.00', 0.10988659641016316)
# ('6.30 < agg__mean_event_nr <= 13.80', -0.10012295450607556)
# ('static__Diagnosis code_M16 <= 0.00', 0.08470560504346308)
# ('1.00 < agg__Producer code_HAEM <= 3.00', -0.06951742698830986)
# (1, 965) 0 [10]
# Generating local Explanations for 0    1004_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9922887  0.00771131]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.5198056591388867)
# ('static__Treatment code_TC603 <= 0.00', -0.15566443767075316)
# ('static__Treatment code_TC101 <= 0.00', 0.10916663203953796)
# ('agg__mean_event_nr <= 6.30', -0.10396580351813345)
# ('static__Diagnosis code_M16 <= 0.00', 0.0985680475653111)
# ('agg__max_timesincecasestart <= 0.00', 0.08553383807924954)
# (1, 965) 0 [10]
# Generating local Explanations for 0    1005_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.23229921 0.7677008 ]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.5249915587953956)
# ('static__Treatment code_TC603 <= 0.00', -0.19510682533431375)
# ('agg__mean_event_nr > 15.93', 0.14132694722064168)
# ('static__Treatment code_TC101 <= 0.00', 0.11164064191706247)
# ('0.00 < static__Specialism code_SC61 <= 1.00', -0.08371026921313908)
# ('agg__max_timesincecasestart <= 0.00', 0.0773721070689492)
# (1, 965) 1 [10]
# Generating local Explanations for 0    1006_10
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9838658  0.01613419]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.5295822429120212)
# ('agg__std_event_nr > 6.83', 0.1140950379959357)
# ('static__Treatment code_TC101 <= 0.00', 0.11171159521248882)
# ('static__Diagnosis code_M16 <= 0.00', 0.1074481366599819)
# ('1.00 < agg__Producer code_HAEM <= 3.00', -0.07999407756472873)
# ('0.00 < agg__Activity code_376480A <= 1.00', -0.07965126749376217)
# (1, 965) 0 [10]
# Generating local Explanations for 0    1007_10
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9959284 0.0040716]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.5248727739953258)
# ('static__Treatment code_TC603 <= 0.00', -0.17292108170161458)
# ('static__Treatment code_TC101 > 0.00', -0.11917727636358949)
# ('agg__mean_event_nr <= 6.30', -0.11272003966340446)
# ('static__Diagnosis code_M16 <= 0.00', 0.09108203163896005)
# ('agg__Producer code_HAEM <= 1.00', 0.07813825977552388)
# Bucket 11
# number events 2282
# Training model iteration  0
# (2145, 26)
# Bucket 12
# number events 2477
# Training model iteration  0
# (2340, 26)
# Bucket 13
# number events 2671
# Training model iteration  0
# (2522, 26)
# Bucket 14
# number events 2863
# Training model iteration  0
# (2688, 26)
# Bucket 15
# number events 3055
# Training model iteration  0
# The number of testing instances is  540
# The total number of columns is 936
# The total accuracy is  1.0
# (2880, 26)
# (1, 936) 1 [15]
# Generating local Explanations for 0    1001_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.01410359 0.9858964 ]
# Explanation for class deviant
# ('static__Treatment code_TC803 > 0.00', 0.4799151531823241)
# ('static__Treatment code_TC603 <= 0.00', -0.18424539465060402)
# ('13.00 < agg__Specialism code.1_SC86 <= 14.00', 0.12655578541686047)
# ('static__Diagnosis code_M16 <= 0.00', 0.10832806886067092)
# ('9.13 < agg__mean_event_nr <= 12.50', -0.10577681277683752)
# ('402.50 < agg__min_open_cases <= 511.00', 0.08380757927689071)
# (1, 936) 1 [15]
# Generating local Explanations for 0    1002_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.09161222 0.9083878 ]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.506189462795391)
# ('agg__mean_event_nr > 14.27', 0.19751842082295482)
# ('static__Treatment code_TC603 <= 0.00', -0.16598090285639944)
# ('static__Diagnosis code_M16 <= 0.00', 0.12348839292017806)
# ('10.75 < agg__Specialism code.1_SC86 <= 13.00', -0.10843835640414762)
# ('0.00 < static__Specialism code_SC61 <= 1.00', -0.0921723296408599)
# (1, 936) 1 [15]
# Generating local Explanations for 0    1003_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.56371295 0.43628705]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.49617257638874224)
# ('static__Treatment code_TC603 <= 0.00', -0.2208644777810664)
# ('agg__mean_event_nr > 14.27', 0.2069911255560509)
# ('agg__max_event_nr > 27.00', 0.14541207584340396)
# ('10.75 < agg__Specialism code.1_SC86 <= 13.00', -0.09583880589440151)
# ('agg__Activity code_AC370000 <= 1.00', -0.09326867907578665)
# (1, 936) 0 [15]
# Generating local Explanations for 0    1004_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.05258369 0.9474163 ]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4881408939313979)
# ('static__Treatment code_TC603 <= 0.00', -0.19921293294174333)
# ('2.00 < agg__Activity code_AC370000 <= 3.00', 0.14468701589209107)
# ('agg__mean_event_nr <= 9.13', -0.11442615817259434)
# ('static__Diagnosis code_M16 <= 0.00', 0.10641482965246747)
# ('agg__Specialism code.1_SC86 <= 10.75', -0.10616177456448907)
# (1, 936) 0 [15]
# Generating local Explanations for 0    1005_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.9820477  0.01795233]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4914932033465717)
# ('static__Treatment code_TC603 <= 0.00', -0.20861226313586512)
# ('2.00 < agg__Activity code_AC370000 <= 3.00', 0.13989930437363185)
# ('static__Diagnosis code_M16 <= 0.00', 0.11058269678227507)
# ('9.13 < agg__mean_event_nr <= 12.50', -0.10235827689379974)
# ('19.00 < agg__max_event_nr <= 25.00', -0.09013569994299062)
# (1, 936) 1 [15]
# Generating local Explanations for 0    1006_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9974847 0.0025153]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.49932049822045443)
# ('static__Treatment code_TC603 <= 0.00', -0.20107883556323694)
# ('agg__mean_event_nr > 14.27', 0.18284546983201289)
# ('13.00 < agg__Specialism code.1_SC86 <= 14.00', 0.1205422980278946)
# ('static__Diagnosis code_M16 <= 0.00', 0.11378307682438342)
# ('1.00 < agg__Activity code_AC370000 <= 2.00', -0.08358742489895732)
# (1, 936) 1 [15]
# Generating local Explanations for 0    1008_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.99208593 0.00791407]
# Explanation for class deviant
# ('static__Treatment code_TC803 > 0.00', 0.48347093046136375)
# ('static__Treatment code_TC603 <= 0.00', -0.2167612986008053)
# ('219.00 < agg__min_open_cases <= 402.50', -0.13686828389191996)
# ('agg__max_event_nr > 27.00', 0.11724328743394247)
# ('static__Diagnosis code_M16 > 0.00', -0.11562762870896796)
# ('agg__Specialism code.1_SC86 <= 10.75', -0.09404364484610801)
# (1, 936) 1 [15]
# Generating local Explanations for 0    1009_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9955773  0.00442274]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.51189811024679)
# ('static__Treatment code_TC603 <= 0.00', -0.1913071803309138)
# ('2.00 < agg__Activity code_AC370000 <= 3.00', 0.1493488036544897)
# ('static__Diagnosis code_M16 <= 0.00', 0.11726529180090273)
# ('9.13 < agg__mean_event_nr <= 12.50', -0.10747207456888472)
# ('19.00 < agg__max_event_nr <= 25.00', -0.08635295130611259)
# (1, 936) 1 [15]
# Generating local Explanations for 0    1010_15
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.02886981 0.9711302 ]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.5025335638269234)
# ('static__Treatment code_TC813 <= 0.00', -0.2135447089234346)
# ('static__Treatment code_TC603 > 0.00', 0.20925118607250145)
# ('2.00 < agg__Activity code_AC370000 <= 3.00', 0.16548662809917566)
# ('13.00 < agg__Specialism code.1_SC86 <= 14.00', 0.11847301752300081)
# ('9.13 < agg__mean_event_nr <= 12.50', -0.09625222019909611)
# (1, 936) 0 [15]
# Generating local Explanations for 0    1011_15
# Name: Case ID, dtype: object
# Actual value  [0]
# [9.999279e-01 7.211082e-05]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4847472703923123)
# ('static__Treatment code_TC603 <= 0.00', -0.18609436751653993)
# ('static__Diagnosis code_M16 <= 0.00', 0.11280350518223414)
# ('agg__Specialism code.1_SC86 > 14.00', 0.09311237534783932)
# ('9.13 < agg__mean_event_nr <= 12.50', -0.0909145642307598)
# ('19.00 < agg__max_event_nr <= 25.00', -0.08400975138653737)
# Bucket 16
# number events 3247
# Training model iteration  0
# (3072, 26)
# Bucket 17
# number events 3439
# Training model iteration  0
# (3264, 26)
# Bucket 18
# number events 3630
# Training model iteration  0
# (3438, 26)
# Bucket 19
# number events 3820
# Training model iteration  0
# (3610, 26)
# Bucket 20
# number events 4010
# Training model iteration  0
# The number of testing instances is  515
# The total number of columns is 923
# The total accuracy is  1.0
# (3800, 26)
# (1, 923) 1 [20]
# Generating local Explanations for 0    1001_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.03340816 0.96659184]
# Explanation for class deviant
# ('static__Treatment code_TC803 > 0.00', 0.41271682027204787)
# ('static__Diagnosis code_DC821 <= 0.00', -0.14806196039381145)
# ('agg__Producer code_SGNA <= 0.00', 0.09549994198665575)
# ('7.52 < agg__std_event_nr <= 8.54', 0.0929045478005296)
# ('agg__Activity code_AC10107 <= 0.00', -0.09195373129040418)
# ('0.00 < agg__Activity code_AC370401 <= 1.00', 0.0905242155493529)
# (1, 923) 1 [20]
# Generating local Explanations for 0    1002_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.37130135 0.62869865]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4083322764964516)
# ('agg__max_event_nr > 27.00', 0.18475942402568307)
# ('agg__std_event_nr > 8.54', 0.13239466824329274)
# ('15.00 < agg__Specialism code.1_SC86 <= 18.00', -0.08857835987644018)
# ('agg__Activity code_AC10107 <= 0.00', -0.08217104934564194)
# ('2.00 < agg__Activity code_AC370000 <= 3.00', 0.07858697880253483)
# (1, 923) 1 [20]
# Generating local Explanations for 0    1003_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9057644  0.09423558]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4129254193283538)
# ('agg__max_event_nr > 27.00', 0.15305053996352322)
# ('agg__std_event_nr > 8.54', 0.1082677309617291)
# ('0.00 < agg__Activity code_AC370401 <= 1.00', 0.09816048837822991)
# ('15.00 < agg__Specialism code.1_SC86 <= 18.00', -0.09328443589185283)
# ('agg__Activity code_AC10107 <= 0.00', -0.09149912233432136)
# (1, 923) 0 [20]
# Generating local Explanations for 0    1004_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.03895205 0.96104795]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4156242917049091)
# ('agg__std_event_nr <= 6.44', -0.13955991221254962)
# ('agg__Producer code_SGAL <= 0.00', -0.12278615805216377)
# ('agg__max_event_nr <= 22.00', -0.10432623703379465)
# ('agg__Specialism code.1_SC86 <= 15.00', -0.09262308171272514)
# ('agg__Activity code_AC370401 <= 0.00', -0.07988617560426416)
# (1, 923) 0 [20]
# Generating local Explanations for 0    1005_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.76897866 0.23102133]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4189416943700929)
# ('agg__Producer code_CHE2 > 12.00', 0.13394182065701807)
# ('agg__Producer code_SGNA <= 0.00', 0.09570834030634064)
# ('6.44 < agg__std_event_nr <= 7.52', -0.0935022081454965)
# ('0.00 < agg__Activity code_376480A <= 1.00', -0.08613905979970739)
# ('agg__Activity code_AC10107 <= 0.00', -0.08409334464419366)
# (1, 923) 1 [20]
# Generating local Explanations for 0    1006_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.93035567 0.06964432]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.42799872622386026)
# ('agg__std_event_nr > 8.54', 0.12117283640589431)
# ('static__Treatment code_TC101 <= 0.00', 0.10035818725030668)
# ('agg__Producer code_SGNA <= 0.00', 0.08922082399338105)
# ('0.00 < agg__Activity code_AC370401 <= 1.00', 0.08364107266555713)
# ('2.00 < agg__Activity code_AC370000 <= 3.00', 0.08074111491681601)
# (1, 923) 1 [20]
# Generating local Explanations for 0    1008_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.74828994 0.25171006]
# Explanation for class deviant
# ('static__Treatment code_TC803 > 0.00', 0.3971280232377467)
# ('agg__Activity code_AC355201 <= 0.00', -0.15536921977043722)
# ('agg__max_event_nr > 27.00', 0.1551237707638457)
# ('agg__std_event_nr > 8.54', 0.12052455987435928)
# ('agg__Activity code_AC10107 <= 0.00', -0.09587505711702425)
# ('agg__Activity code_AC370401 <= 0.00', -0.08932144921334824)
# (1, 923) 1 [20]
# Generating local Explanations for 0    1009_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.9482215  0.05177851]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4241977434197942)
# ('agg__Activity code_AC355201 <= 0.00', -0.13900302530785824)
# ('agg__Producer code_CHE2 > 12.00', 0.13885205247499574)
# ('44.00 < static__Age <= 58.00', 0.09337135318338222)
# ('agg__Activity code_AC10107 <= 0.00', -0.09113986153071962)
# ('agg__Producer code_SGNA <= 0.00', 0.08847119115393089)
# (1, 923) 1 [20]
# Generating local Explanations for 0    1010_20
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.00877643 0.9912236 ]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.40827531580568893)
# ('static__Treatment code_TC813 <= 0.00', -0.17703558809423606)
# ('agg__Producer code_CHE2 > 12.00', 0.15330295494221427)
# ('22.00 < agg__max_event_nr <= 25.00', -0.08966044450462927)
# ('2.00 < agg__Activity code_AC370000 <= 3.00', 0.08169421225762953)
# ('agg__Producer code_SGNA <= 0.00', 0.0727595487768943)
# (1, 923) 0 [20]
# Generating local Explanations for 0    1011_20
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.980759   0.01924098]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.38669861953539036)
# ('agg__std_event_nr <= 6.44', -0.13105964099015363)
# ('agg__Activity code_AC370000 <= 2.00', -0.10545955491027761)
# ('agg__max_event_nr <= 22.00', -0.10276256970385675)
# ('agg__Activity code_AC10107 <= 0.00', -0.09833899544241037)
# ('0.00 < agg__Activity code_AC370401 <= 1.00', 0.09693267834674171)
# Bucket 21
# number events 4200
# Training model iteration  0
# (3990, 26)
# Bucket 22
# number events 4389
# Training model iteration  0
# (4158, 26)
# Bucket 23
# number events 4578
# Training model iteration  0
# (4347, 26)
# Bucket 24
# number events 4766
# Training model iteration  0
# (4512, 26)
# Bucket 25
# number events 4954
# Training model iteration  0
# The number of testing instances is  491
# The total number of columns is 911
# The total accuracy is  1.0
# (4700, 26)
# (1, 911) 1 [25]
# Generating local Explanations for 0    1001_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.03516895 0.96483105]
# Explanation for class deviant
# ('static__Treatment code_TC803 > 0.00', 0.4263671493706407)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.16730585591814395)
# ('23.00 < agg__Specialism code.1_SC86 <= 24.00', 0.1629825333866416)
# ('agg__Activity code_AC10107 <= 0.00', -0.12563334597892087)
# ('agg__Producer code_SGNA <= 0.00', 0.11815851180597334)
# ('static__Specialism code_SC61 <= 0.00', 0.11691497072661912)
# (1, 911) 1 [25]
# Generating local Explanations for 0    1002_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.97644836 0.02355167]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.43376297463574137)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.15152429421301208)
# ('agg__max_event_nr > 28.00', 0.13780682680779377)
# ('19.00 < agg__Specialism code.1_SC86 <= 23.00', -0.13174321539872777)
# ('agg__Activity code_AC10107 <= 0.00', -0.11373852366832049)
# ('0.00 < static__Specialism code_SC61 <= 1.00', -0.1027170573910233)
# (1, 911) 1 [25]
# Generating local Explanations for 0    1003_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.990191   0.00980904]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4328732871500717)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.14506332192888954)
# ('19.00 < agg__Specialism code.1_SC86 <= 23.00', -0.14027592177439044)
# ('agg__Activity code_AC10107 <= 0.00', -0.12445015192368529)
# ('static__Specialism code_SC61 <= 0.00', 0.12253372071483368)
# ('6.00 < agg__mean_month <= 9.00', 0.09606598063650736)
# (1, 911) 0 [25]
# Generating local Explanations for 0    1004_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.0055452 0.9944548]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.42894865919164754)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.15739655023638838)
# ('agg__Activity code_AC10107 <= 0.00', -0.13380070697053384)
# ('agg__Specialism code.1_SC86 <= 19.00', -0.1301693958652538)
# ('agg__max_event_nr > 28.00', 0.11851322523854826)
# ('6.00 < agg__mean_month <= 9.00', 0.11431561545065769)
# (1, 911) 0 [25]
# Generating local Explanations for 0    1005_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [0.97223645 0.02776352]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.4194157302963262)
# ('agg__Activity code_AC10107 <= 0.00', -0.1404929212499793)
# ('agg__Specialism code.1_SC86 > 24.00', 0.13316399854917504)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.1304421223935228)
# ('0.00 < static__Specialism code_SC61 <= 1.00', -0.10982055993142395)
# ('agg__Producer code_SGNA <= 0.00', 0.10419495476309827)
# (1, 911) 1 [25]
# Generating local Explanations for 0    1006_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.99877    0.00123001]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.43410717389503106)
# ('23.00 < agg__Specialism code.1_SC86 <= 24.00', 0.17199392942560696)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.14138221861385628)
# ('agg__Activity code_AC10107 <= 0.00', -0.1388091208726553)
# ('agg__Producer code_SGNA <= 0.00', 0.12573650193378635)
# ('0.00 < static__Specialism code_SC61 <= 1.00', -0.11214578240870184)
# (1, 911) 1 [25]
# Generating local Explanations for 0    1008_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.03243643 0.96756357]
# Explanation for class deviant
# ('static__Treatment code_TC803 > 0.00', 0.43021654267498605)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.15595180704722747)
# ('19.00 < agg__Specialism code.1_SC86 <= 23.00', -0.14167138930992904)
# ('agg__Activity code_AC10107 <= 0.00', -0.12619805256639186)
# ('agg__max_event_nr > 28.00', 0.12171468340577814)
# ('static__Specialism code_SC61 <= 0.00', 0.11665375539286456)
# (1, 911) 1 [25]
# Generating local Explanations for 0    1009_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.95909244 0.04090759]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.42927943993453155)
# ('agg__Activity code_AC10107 <= 0.00', -0.14293672619385792)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.13151558615661105)
# ('0.00 < static__Specialism code_SC61 <= 1.00', -0.12439619276213745)
# ('agg__Producer code_SGNA <= 0.00', 0.10731584221578105)
# ('agg__Producer code_LVPT <= 0.00', -0.10193746422330054)
# (1, 911) 1 [25]
# Generating local Explanations for 0    1010_25
# Name: Case ID, dtype: object
# Actual value  [1]
# [0.25381416 0.74618584]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.41148354558197475)
# ('23.00 < agg__Specialism code.1_SC86 <= 24.00', 0.1566335357560712)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.13113479276741466)
# ('agg__Producer code_SGNA <= 0.00', 0.11656586938691585)
# ('static__Specialism code_SC61 <= 0.00', 0.11306661185048227)
# ('agg__Activity code_AC10107 <= 0.00', -0.10350525846733258)
# (1, 911) 0 [25]
# Generating local Explanations for 0    1011_25
# Name: Case ID, dtype: object
# Actual value  [0]
# [9.9998665e-01 1.3351095e-05]
# Explanation for class deviant
# ('static__Treatment code_TC803 <= 0.00', -0.41282381641421406)
# ('289.76 < agg__mean_open_cases <= 442.00', -0.15387173865743867)
# ('agg__Activity code_AC10107 <= 0.00', -0.14118107104421146)
# ('19.00 < agg__Specialism code.1_SC86 <= 23.00', -0.13047081339184266)
# ('0.00 < static__Specialism code_SC61 <= 1.00', -0.11784715062633944)
# ('agg__max_event_nr <= 25.00', -0.10353717440006732)
# Bucket 26
# number events 5142
# Training model iteration  0
# (4888, 26)
# Bucket 27
# number events 5326
# Training model iteration  0
# (4968, 26)
# Bucket 28
# number events 5509
# Training model iteration  0
# (5124, 26)
# Bucket 29
# number events 5689
# Training model iteration  0
# (5220, 26)
# Bucket 30
# number events 5869
# Training model iteration  0
# (5400, 26)
# Bucket 31
# number events 6044
# Training model iteration  0
# (5425, 26)
# Bucket 32
# number events 6216
# Training model iteration  0
# (5504, 26)
# Bucket 33
# number events 6385
# Training model iteration  0
# (5577, 26)
# Bucket 34
# number events 6551
# Training model iteration  0
# (5644, 26)
# Bucket 35
# number events 6714
# Training model iteration  0
# (5705, 26)
# Bucket 36
# number events 6874
# Training model iteration  0
# (5760, 26)
# Bucket 37
# number events 7030
# Training model iteration  0
# (5772, 26)
# Bucket 38
# number events 7185
# Training model iteration  0
# (5890, 26)
# Bucket 39
# number events 7338
# Training model iteration  0
# (5967, 26)
# Bucket 40
# number events 7491
# Training model iteration  0
# (6120, 26)
# bpic2011_f4 prefix_agg xgboost 1 auc 0.7937110985369009
# bpic2011_f4 prefix_agg xgboost 2 auc 0.7483308907344082
# bpic2011_f4 prefix_agg xgboost 3 auc 0.7373051127950527
# bpic2011_f4 prefix_agg xgboost 4 auc 0.8065422254440016
# bpic2011_f4 prefix_agg xgboost 5 auc 0.7565225671300706
# bpic2011_f4 prefix_agg xgboost 6 auc 0.770928231602389
# bpic2011_f4 prefix_agg xgboost 7 auc 0.7683976110942403
# bpic2011_f4 prefix_agg xgboost 8 auc 0.725079888671271
# bpic2011_f4 prefix_agg xgboost 9 auc 0.7180703020307183
# bpic2011_f4 prefix_agg xgboost 10 auc 0.7677559014534584
# bpic2011_f4 prefix_agg xgboost 11 auc 0.7835488658045368
# bpic2011_f4 prefix_agg xgboost 12 auc 0.785244859020564
# bpic2011_f4 prefix_agg xgboost 13 auc 0.7695024077046548
# bpic2011_f4 prefix_agg xgboost 14 auc 0.7940438529508018
# bpic2011_f4 prefix_agg xgboost 15 auc 0.767972073742773
# bpic2011_f4 prefix_agg xgboost 16 auc 0.7730991600305444
# bpic2011_f4 prefix_agg xgboost 17 auc 0.7568452056288862
# bpic2011_f4 prefix_agg xgboost 18 auc 0.7651147396293027
# bpic2011_f4 prefix_agg xgboost 19 auc 0.7874331550802139
# bpic2011_f4 prefix_agg xgboost 20 auc 0.7901069518716577
# bpic2011_f4 prefix_agg xgboost 21 auc 0.7717245989304813
# bpic2011_f4 prefix_agg xgboost 22 auc 0.7781278127812781
# bpic2011_f4 prefix_agg xgboost 23 auc 0.780040504050405
# bpic2011_f4 prefix_agg xgboost 24 auc 0.7509090909090909
# bpic2011_f4 prefix_agg xgboost 25 auc 0.7395454545454545
# bpic2011_f4 prefix_agg xgboost 26 auc 0.71375
# bpic2011_f4 prefix_agg xgboost 27 auc 0.7150804924242424
# bpic2011_f4 prefix_agg xgboost 28 auc 0.810287081339713
# bpic2011_f4 prefix_agg xgboost 29 auc 0.7881596835990606
# bpic2011_f4 prefix_agg xgboost 30 auc 0.8010134717587442
# bpic2011_f4 prefix_agg xgboost 31 auc 0.7955317481055657
# bpic2011_f4 prefix_agg xgboost 32 auc 0.7308004326663061
# bpic2011_f4 prefix_agg xgboost 33 auc 0.7380218548613058
# bpic2011_f4 prefix_agg xgboost 34 auc 0.7962236746550472
# bpic2011_f4 prefix_agg xgboost 35 auc 0.8600060277275468
# bpic2011_f4 prefix_agg xgboost 36 auc 0.8212719298245614
# bpic2011_f4 prefix_agg xgboost 37 auc 0.8538359788359788
# bpic2011_f4 prefix_agg xgboost 38 auc 0.8742454728370221
# bpic2011_f4 prefix_agg xgboost 39 auc 0.8678398895790199
# bpic2011_f4 prefix_agg xgboost 40 auc 0.8624913733609386
# bpic2011_f4 prefix_agg xgboost -1 -1 auc 0.777922661104445

# %% [markdown]
# ### Plot Local Explanations

# %%
rc={'axes.labelsize': 12, 'xtick.labelsize': 13, 'ytick.labelsize': 13 , 'axes.titlesize': 10}
sns.set(rc)
sns.set_style("whitegrid")
# %matplotlib inline
for pre, exp in exp_ddict.items():
    #print('Explanations for prefix length ', pre)
    fig = exp.as_pyplot_figure()
# Out:
# Explanations for prefix length  6
# Explanations for prefix length  7
# Explanations for prefix length  8
# Explanations for prefix length  9
# Explanations for prefix length  11
# Explanations for prefix length  12
# Explanations for prefix length  13
# Explanations for prefix length  14
# Explanations for prefix length  16
# Explanations for prefix length  17
# Explanations for prefix length  18
# Explanations for prefix length  19
# Explanations for prefix length  20
# Explanations for prefix length  21
# Explanations for prefix length  22
# Explanations for prefix length  23
# Explanations for prefix length  24
# Explanations for prefix length  25
# Explanations for prefix length  26
# Explanations for prefix length  27
# Explanations for prefix length  28
# Explanations for prefix length  29
# Explanations for prefix length  30
# Explanations for prefix length  31
# Explanations for prefix length  32

# %%
print('printing global feature importance of the random forest classifier') 
rc={'axes.labelsize': 14, 'xtick.labelsize': 14, 'ytick.labelsize': 14 ,'axes.titlesize': 15}
sns.set(rc)
sns.set_style("whitegrid")
for pre, importance in importance_dict.items():
    if(pre==25):
        print('printing global feature importance of the random forest classifier', pre, importance.head(10)) 
        title = 'Prefix length {} bucket: prefix, encoding: aggregation, classifier: xgboost'.format(pre)
        var_imp_plot(importance, title, 10)
# Out:
# printing global feature importance of the random forest classifier
# printing global feature importance of the random forest classifier 25                                feature  feature_importance
# 0         static__Treatment code_TC813            0.216536
# 1         static__Treatment code_TC603            0.130983
# 2          agg__Activity code_AC350503            0.064189
# 3          agg__Activity code_AC355201            0.048598
# 4         static__Treatment code_TC103            0.035886
# 5         static__Treatment code_TC113            0.033596
# 6         static__Treatment code_TC803            0.032766
# 7          agg__Activity code_AC370000            0.028829
# 8  static__Diagnosis_maligniteit vulva            0.028756
# 9         static__Treatment code_TC101            0.026357
